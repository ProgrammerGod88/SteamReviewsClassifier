# %%
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations and array manipulation
import matplotlib.pyplot as plt  # Data visualization
import seaborn as sns  # Advanced data visualization
import sklearn  # Machine learning algorithms and tools
from sklearn.model_selection import train_test_split  # Splitting data for training and testing
from sklearn.preprocessing import StandardScaler  # Data preprocessing

# %%
dota_reviews = pd.read_csv("E:\Data Science Time\SteamReviewClassifier\DataSets\Dota2_Steam_Reviews.csv")

# %%
dota_reviews
# Out:
#               id language                                             review  \
# 0      157358921  english                                                  .
# 1      157358663  english  very much hair loss game, too much rage in SEA...
# 2      157358215  english                             best game in the world
# 3      157357777  english                                               GGWP
# 4      157357674  english                                                NaN
# ...          ...      ...                                                ...
# 55131  128187631  english           Thx for the Free Arcana ,Dotapluss, BP .
# 55132  128187101  english                                  entertaining game
# 55133  128186766  english                              za goy sda shu amjilt
# 55134  128185443  english  Never played a single match in dota, Autochess...
# 55135  128184383  english                              Really good MOBA game
#
# ...

# %%
dota_reviews_language = dota_reviews.language

# %%
dota_reviews_language
# Out:
# 0        english
# 1        english
# 2        english
# 3        english
# 4        english
#           ...
# 55131    english
# 55132    english
# 55133    english
# 55134    english
# 55135    english
# Name: language, Length: 55136, dtype: object

# %%
different_languages = dota_reviews_language.value_counts()

# %%
print(different_languages)
# Out:
# english    55136
# Name: language, dtype: int64

# %%
dota_reviews["review"].dropna(inplace=True)

# %%
dota_reviews.head()
# Out:
#           id language                                             review  \
# 0  157358921  english                                                  .
# 1  157358663  english  very much hair loss game, too much rage in SEA...
# 2  157358215  english                             best game in the world
# 3  157357777  english                                               GGWP
# 4  157357674  english                                                NaN
#
#                created  voted_up  votes_up  comment_count  steam_purchase  \
# 0  2024-02-01 21:29:20      True         0              0           False
# 1  2024-02-01 21:24:32      True         0              0           False
# 2  2024-02-01 21:16:32      True         0              0           False
# 3  2024-02-01 21:09:18      True         0              0           False
# 4  2024-02-01 21:07:14      True         0              0           False
#
#    recieved_for_free  written_during_early_access  author_num_games_owned  \
# ...

# %%
        
dota_reviews["review"]=dota_reviews["review"].str.lower()

# %% [raw]
# dota_reviews.dropna(subset=['review'], inplace=True)

# %%
dota_reviews
# Out:
#               id language                                             review  \
# 0      157358921  english                                                  .
# 1      157358663  english  very much hair loss game, too much rage in sea...
# 2      157358215  english                             best game in the world
# 3      157357777  english                                               ggwp
# 5      157356996  english  don`t ever play this stupid game with stupid m...
# ...          ...      ...                                                ...
# 55131  128187631  english           thx for the free arcana ,dotapluss, bp .
# 55132  128187101  english                                  entertaining game
# 55133  128186766  english                              za goy sda shu amjilt
# 55134  128185443  english  never played a single match in dota, autochess...
# 55135  128184383  english                              really good moba game
#
# ...

# %%
dota_reviews.count
# Out:
# <bound method DataFrame.count of               id language                                             review  \
# 0      157358921  english                                                  .
# 1      157358663  english  very much hair loss game, too much rage in sea...
# 2      157358215  english                             best game in the world
# 3      157357777  english                                               ggwp
# 5      157356996  english  don`t ever play this stupid game with stupid m...
# ...          ...      ...                                                ...
# 55131  128187631  english           thx for the free arcana ,dotapluss, bp .
# 55132  128187101  english                                  entertaining game
# 55133  128186766  english                              za goy sda shu amjilt
# 55134  128185443  english  never played a single match in dota, autochess...
# 55135  128184383  english                              really good moba game
#
# ...

# %%
from langdetect import detect

# %%
def removeNonEnglish(Review_Text):
    try:
        language = detect(Review_Text)
        if language == "en":
            return True  
        else:
            return False  
    except Exception as e:
        return False
    

English_Reviews = dota_reviews[dota_reviews["review"].apply(removeNonEnglish)]

# %%
English_Reviews.head()
# Out:
#            id language                                             review  \
# 1   157358663  english  very much hair loss game, too much rage in sea...
# 2   157358215  english                             best game in the world
# 5   157356996  english  don`t ever play this stupid game with stupid m...
# 7   157355418  english                           played for a bit. is ok.
# 12  157350551  english                                 having lots of fun
#
#                 created  voted_up  votes_up  comment_count  steam_purchase  \
# 1   2024-02-01 21:24:32      True         0              0           False
# 2   2024-02-01 21:16:32      True         0              0           False
# 5   2024-02-01 20:55:45     False         0              0           False
# 7   2024-02-01 20:29:55      True         0              0           False
# 12  2024-02-01 19:03:47      True         0              0           False
#
# ...

# %%
English_Reviews.count()
# Out:
# id                                31527
# language                          31527
# review                            31527
# created                           31527
# voted_up                          31527
# votes_up                          31527
# comment_count                     31527
# steam_purchase                    31527
# recieved_for_free                 31527
# written_during_early_access       31527
# author_num_games_owned            31527
# author_num_reviews                31527
# author_playtime_forever           31527
# author_playtime_last_two_weeks    31527
# author_playtime_at_review         31527
# author_last_played                31527
# dtype: int64

# %%
English_Reviews.sort_values("author_playtime_forever", ascending=False)
# Out:
#               id language                                             review  \
# 39532  137106604  english                        why update during a game?\n
# 15648  149225056  english                       this game becomes your life.
# 21302  147763741  english  the game is great, and the updates are always ...
# 12439  150225249  english  be like me and waste 34 thousand hours of your...
# 29506  143269671  english        good to jerk off when playing this game! :d
# ...          ...      ...                                                ...
# 26474  145111266  english                                      the best game
# 9806   151299125  english         better play in sims dont try this game !!!
# 533    156924059  english  this game gave me:\n\n· acne\n· aids\n· allerg...
# 1257   156435624  english  if u have bad wifi don't download this it migh...
# 50017  131272043  english  this is not a game that is healthy to play unl...
#
# ...

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Zain\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
English_Reviews.loc[:, "tokens"] = English_Reviews["review"].apply(word_tokenize)
# Out:
# C:\Users\Zain\AppData\Local\Temp\ipykernel_6180\3900441961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   English_Reviews.loc[:, "tokens"] = English_Reviews["review"].apply(word_tokenize)

# %%
English_Reviews
# Out:
#               id language                                             review  \
# 1      157358663  english  very much hair loss game, too much rage in sea...
# 2      157358215  english                             best game in the world
# 5      157356996  english  don`t ever play this stupid game with stupid m...
# 7      157355418  english                           played for a bit. is ok.
# 12     157350551  english                                 having lots of fun
# ...          ...      ...                                                ...
# 55126  128191331  english  they finally fixed the loading issue on the ba...
# 55127  128191292  english  good balancing and quality of life, although t...
# 55128  128190648  english                                      game is happy
# 55131  128187631  english           thx for the free arcana ,dotapluss, bp .
# 55134  128185443  english  never played a single match in dota, autochess...
#
# ...

# %%
print(English_Reviews["tokens"].iloc[0:5])
# Out:
# 1     [very, much, hair, loss, game, ,, too, much, r...
# 2                          [best, game, in, the, world]
# 5     [don, `, t, ever, play, this, stupid, game, wi...
# 7                   [played, for, a, bit, ., is, ok, .]
# 12                              [having, lots, of, fun]
# Name: tokens, dtype: object

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(example_sent)
# converts the words in word_tokens to lower case and then checks whether 
#they are present in stop_words or not

filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\Zain/nltk_data'
# ...
